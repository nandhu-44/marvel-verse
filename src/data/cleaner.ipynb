# %%
import pandas as pd

# %%
movies_json_file = "./marvel_movies.json";

# %%
df = pd.read_json(movies_json_file);

# %%
df.columns;
# Out:
# Index(['backdrop_path', 'genre_ids', 'id', 'original_language', 'overview',
#        'popularity', 'poster_path', 'release_date', 'title', 'video',
#        'vote_average', 'vote_count', 'belongs_to_collection', 'genres',
#        'homepage', 'imdb_id', 'origin_country', 'original_title', 'revenue',
#        'runtime', 'spoken_languages', 'tagline', 'cast'],
#       dtype='object')

# %%
# find all with no backdrop_path or no poster_path
df[(df['backdrop_path'].isnull()) | (df['poster_path'].isnull())]
# Out:
# Empty DataFrame
# Columns: [backdrop_path, genre_ids, id, original_language, overview, popularity, poster_path, release_date, title, video, vote_average, vote_count, belongs_to_collection, genres, homepage, imdb_id, origin_country, original_title, revenue, runtime, spoken_languages, tagline, cast]
# Index: []
#
# [0 rows x 23 columns]

# %%
# drop these values
df.dropna(subset=['backdrop_path', 'poster_path'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# see where title and original_title are different
df[df['title'] != df['original_title']]
# Out:
# Empty DataFrame
# Columns: [backdrop_path, genre_ids, id, original_language, overview, popularity, poster_path, release_date, title, video, vote_average, vote_count, belongs_to_collection, genres, homepage, imdb_id, origin_country, original_title, revenue, runtime, spoken_languages, tagline, cast]
# Index: []
#
# [0 rows x 23 columns]

# %%
# As no title is different from original_title, we can drop original_title
df.drop(columns=['original_title'], inplace=True)

# %%
# Check where releae_date is an empty string
df[df['release_date'] == '']

# drop these values with empty release_date
df = df[df['release_date'] != '']
df.reset_index(drop=True, inplace=True)
df
# Out:
#                        backdrop_path              genre_ids       id  \
# 0   /h0rLRgh21cQS2Mrou9fEcZQuaku.jpg                  [878]  1003598
# 1   /vrncuH8IDqQ5M47XPk19yxY8o1b.jpg                  [878]  1003596
# 2   /hFtJz4TvoiJJcw2ZOMdhK22aU9P.jpg                   [14]   617127
# 3   /5qfAg7HVX1ZUZCObYCisSI3yz0h.jpg              [878, 12]   617126
# 4   /fS3OVEfYkW1BNRydu1GZrfdbqvu.jpg               [28, 12]   986056
# ..                               ...                    ...      ...
# 83  /7ff2FyFmskEFfmXHkxuqVr47DiG.jpg          [878, 12, 28]     1979
# 84  /w1oD1MzHjnBJc5snKupIQaSBLIh.jpg          [28, 12, 878]      559
# 85  /x6gi2yn51sjRBMt6xeVTPVGFeSB.jpg  [28, 12, 16, 14, 878]    13647
# 86  /7zS58YPAw002RNejOF1vNB3XHbW.jpg           [53, 28, 14]     1250
# 87  /xv77AFzMUiTuUsC5qn31jBB21An.jpg      [12, 16, 28, 878]    14611
#
#    original_language                                           overview  \
# 0                 en  An upcoming film in Phase 6 of the Marvel Cine...
# 1                 en  An upcoming film in the Marvel Cinematic Unive...
# 2                 en  A film set in the Marvel Cinematic Universe (M...
# 3                 en  Set in the Marvel Cinematic Universe (MCU) and...
# 4                 en  Depressed assassin Yelena Belova teams up alon...
# ..               ...                                                ...
# 83                en  The Fantastic Four return to the big screen as...
# 84                en  The seemingly invincible Spider-Man goes up ag...
# 85                en  When a cocky industrialist's efforts to raise ...
# 86                en  In order to save his dying father, young stunt...
# 87                en  Mysterious Wakanda lies in the darkest heart o...
#
#     popularity                       poster_path release_date  \
# 0       20.650  /f0YBuh4hyiAheXhh4JnJWoKi9g5.jpg   2027-05-05
# 1       73.318  /eO6OdA4RDRWeCVlDMcsoxWYFySD.jpg   2026-04-29
# 2       18.877  /fKqA4rgVJwrM7Gb3tQ9TGHnu8Tr.jpg   2025-11-05
# 3       16.251  /zOiVyH3hJ4e7rEUBLGuinhOonh1.jpg   2025-07-23
# 4       38.650  /hQYEA4Ty1RlxsToWMYLE2RzSc0N.jpg   2025-04-30
# ..         ...                               ...          ...
# 83      36.514  /f3ldtPF7SESMcyAIyIJHBLlBBkr.jpg   2007-06-13
# 84      76.505  /qFmwhVUoUSXjkKRmca5yGDEXBIj.jpg   2007-05-01
# 85      12.850  /eebNTSRa5Hh5skPKGdGJIJpo9Ls.jpg   2007-01-23
# 86      55.825  /8LaVQiXBsnlo7MXCPK1nXTVARUZ.jpg   2007-01-15
# 87      15.913  /2bfVNvLKWaxFh1LiOKlvxgiHOXn.jpg   2006-08-08
#
#                                         title  video  ...  \
# 0                       Avengers: Secret Wars  False  ...
# 1                          Avengers: Doomsday  False  ...
# 2                                       Blade  False  ...
# 3             The Fantastic Four: First Steps  False  ...
# 4                               Thunderbolts*  False  ...
# ..                                        ...    ...  ...
# 83  Fantastic Four: Rise of the Silver Surfer  False  ...
# 84                               Spider-Man 3  False  ...
# 85                    The Invincible Iron Man  False  ...
# 86                                Ghost Rider  False  ...
# 87                        Ultimate Avengers 2  False  ...
#
#                                 belongs_to_collection  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 83  {'id': 9744, 'name': 'Fantastic Four Collectio...
# 84  {'id': 556, 'name': 'Spider-Man Collection', '...
# 85                                               None
# 86  {'id': 90306, 'name': 'Ghost Rider Collection'...
# 87  {'id': 286904, 'name': 'Ultimate Avengers Coll...
#
#                                                genres  \
# 0            [{'id': 878, 'name': 'Science Fiction'}]
# 1            [{'id': 878, 'name': 'Science Fiction'}]
# 2                     [{'id': 14, 'name': 'Fantasy'}]
# 3   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ..                                                ...
# 83  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 84  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 85  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 86  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 87  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
#
#                                              homepage     imdb_id  \
# 0   https://www.marvel.com/movies/avengers-secret-...  tt21361444
# 1   https://www.marvel.com/movies/avengers-kang-dy...  tt21357150
# 2                 https://www.marvel.com/movies/blade  tt10671440
# 3        https://www.marvel.com/movies/fantastic-four  tt10676052
# 4          https://www.marvel.com/movies/thunderbolts  tt20969586
# ..                                                ...         ...
# 83  https://family.20thcenturystudios.com/movies/f...   tt0486576
# 84     https://www.sonypictures.com/movies/spiderman3   tt0413300
# 85                                                      tt0903135
# 86     https://www.sonypictures.com/movies/ghostrider   tt0259324
# 87                                                      tt0803093
#
#    origin_country    revenue runtime  \
# 0            [US]          0       0
# 1            [US]          0       0
# 2            [US]          0       0
# 3            [US]          0       0
# 4            [US]          0       0
# ..            ...        ...     ...
# 83           [US]  301913131      92
# 84           [US]  894983373     139
# 85           [US]          0      83
# 86           [US]  228738393     114
# 87           [US]          0      73
#
#                                      spoken_languages  \
# 0   [{'english_name': 'English', 'iso_639_1': 'en'...
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...
# 2   [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...
# ..                                                ...
# 83  [{'english_name': 'English', 'iso_639_1': 'en'...
# 84  [{'english_name': 'English', 'iso_639_1': 'en'...
# 85  [{'english_name': 'Czech', 'iso_639_1': 'cs', ...
# 86  [{'english_name': 'English', 'iso_639_1': 'en'...
# 87  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                               tagline  \
# 0
# 1
# 2
# 3
# 4                           Careful who you assemble.
# ..                                                ...
# 83                 Discover the secret of the Surfer.
# 84                   The greatest battle lies within.
# 85  A Lone Warrior. A Suit of Armor. Our Only Hope...
# 86  Long ago he made a deal to save someone he loved.
# 87  To save humanity, the Earth's mightiest heroes...
#
#                                                  cast
# 0   [{'adult': False, 'gender': 2, 'id': 3223, 'kn...
# 1   [{'adult': False, 'gender': 2, 'id': 3223, 'kn...
# 2   [{'adult': False, 'gender': 2, 'id': 932967, '...
# 3   [{'adult': False, 'gender': 2, 'id': 1253360, ...
# 4   [{'adult': False, 'gender': 1, 'id': 1373737, ...
# ..                                                ...
# 83  [{'adult': False, 'gender': 2, 'id': 65524, 'k...
# 84  [{'adult': False, 'gender': 2, 'id': 2219, 'kn...
# 85  [{'adult': False, 'gender': 2, 'id': 31536, 'k...
# 86  [{'adult': False, 'gender': 2, 'id': 2963, 'kn...
# 87  [{'adult': False, 'gender': 0, 'id': 87174, 'k...
#
# [88 rows x 22 columns]

# %%
# save to cleaned_data.json file
df.to_json("cleaned_data.json", orient='records')
